# %% [markdown]
# # 3. Convolutional Neural Network

# %%
import os
import cv2
import numpy as np
from keras.applications import VGG16
from keras.applications.vgg16 import preprocess_input
import pandas as pd

def compute_CNN(image, resize_dim=(224, 224)):
    # Resize the image
    resized_image = cv2.resize(image, resize_dim)
    # Preprocess input for VGG16 model
    preprocessed_image = preprocess_input(resized_image)
    # Expand dimensions to match VGG input shape
    preprocessed_image = np.expand_dims(preprocessed_image, axis=0)
    # Use pre-trained VGG16 model
    model = VGG16(weights='imagenet', include_top=False)
    # Extract features
    features = model.predict(preprocessed_image)
    # Flatten the features
    flattened_features = features.flatten()
    return flattened_features

# Function to save CNN features along with car name and image name to a CSV file
def save_to_csv(data, filename):
    np.savetxt(filename, data, delimiter=',', fmt='%s')

# Path to the folder containing images
folder_path = "images/"
# Load the CSV containing car name and image name mapping
csv_data = np.genfromtxt('Datasets/raw/CarsWithStocksPrices.csv', delimiter=',', dtype=str, skip_header=1)

# Initialize list to store extracted features
feature_data = []

# Iterate over each entry in the mapping CSV
for entry in csv_data:
    # Extract car name and image name
    car_name = entry[0]
    image_name = entry[4]
    price = entry[3]
    stock = entry[2]
    # Construct full path to the image
    image_path = os.path.join(folder_path, image_name+  '.jpg')
    print("Image path:", image_path)  # Print the image path for debugging
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        print("Error: Unable to load image", image_path)
        continue
    # Compute CNN features
    cnn_features = compute_CNN(image)
    # Append car name, image name, and features to the list
    feature_data.append(np.hstack((car_name, image_name, price, stock, cnn_features)))

# Save the feature data to CSV
save_to_csv(feature_data, 'Datasets/CNN_car_features.csv')

# Read the CSV file into a DataFrame
df = pd.read_csv('Datasets/CNN_car_features.csv')
df = df.iloc[:, 1:]

# Rename the columns
df.columns = ["CarName", "Price","Stock"] + [f"Feature_{i}" for i in range(1, len(df.columns) - 2)]

# Save the DataFrame back to the same CSV file
df.to_csv('Datasets/CNN_car_features.csv', index=False)



print("Features saved to CNN_car_features.csv")
# Out:
# Image path: images/BMW 1 Series 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Image path: images/BMW 2 Series Active Tourer 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Image path: images/BMW 2 Series Gran Coupe 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# Image path: images/BMW 3 Series 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Image path: images/BMW 4 Series 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 853ms/step
# Image path: images/BMW 4 Series Convertible 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Image path: images/BMW 5 Series 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Image path: images/BMW 6 Series 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Image path: images/BMW 7 Series 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# Image path: images/BMW 7 Series 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# Image path: images/BMW 8 Series 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# Image path: images/BMW i3 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Image path: images/BMW i4 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Image path: images/BMW i7 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Image path: images/BMW i8 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# Image path: images/BMW iX 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Image path: images/BMW iX3 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 689ms/step
# Image path: images/BMW M2 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# Image path: images/BMW M8 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Image path: images/BMW X1 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# Image path: images/BMW X2 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# Image path: images/BMW X3 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Image path: images/BMW X3 M 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 955ms/step
# Image path: images/BMW X4 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Image path: images/BMW X5 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# Image path: images/BMW X5 M 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# Image path: images/BMW X6 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Image path: images/BMW X7 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# Image path: images/BMW XM 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Image path: images/BMW Z4 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# Image path: images/Buick Enclave 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# Image path: images/Buick Encore 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Image path: images/Buick Envision 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Image path: images/BYD Dolphin 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# Image path: images/BYD e3 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Image path: images/BYD e3 DM-i 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Image path: images/BYD e5 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Image path: images/BYD e6 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# Image path: images/BYD Han 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# Image path: images/BYD Qin 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# Image path: images/BYD Qin Plus 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Image path: images/BYD Qin Pro 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Image path: images/BYD Song 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Image path: images/BYD Song Max 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Image path: images/BYD Song Plus 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# Image path: images/BYD Song Pro 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# Image path: images/BYD Tang 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# Image path: images/BYD Tang DM-i 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Image path: images/BYD Yuan 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Image path: images/Cadillac CT5 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Image path: images/Cadillac Escalade 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Image path: images/Cadillac XT5 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Image path: images/Cadillac XT6 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# Image path: images/Chevrolet Camaro 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# Image path: images/Chevrolet Impala 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Image path: images/Chevrolet Malibu 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Image path: images/Chevrolet Silverado 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Image path: images/Chevrolet Trailblazer 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Image path: images/Chevrolet Traverse 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# Image path: images/Ferrari 296 GTB 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# Image path: images/Ferrari 488 Pista 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# Image path: images/Ferrari 488 Pista Spider 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Image path: images/Ferrari 488 Spider 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# Image path: images/Ferrari 812 GTS 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# Image path: images/Ferrari 812 Superfast 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# Image path: images/Ferrari F12 Berlinetta 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# Image path: images/Ferrari F8 Spider 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# Image path: images/Ferrari F8 Tributo 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step
# Image path: images/Ferrari F8 Tributo 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# Image path: images/Ferrari Portofino 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Image path: images/Ferrari Portofino M 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# Image path: images/Ferrari Portofino M 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Image path: images/Ferrari Roma 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# Image path: images/Ferrari SF90 Spider 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step
# Image path: images/Ferrari SF90 Stradale 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# Image path: images/Ferrari SF90 Stradale Assetto Fiorano 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 739ms/step
# Image path: images/Ford Bronco 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# Image path: images/Ford EcoSport 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Image path: images/Ford Edge 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# Image path: images/Ford Escape 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# Image path: images/Ford Expedition 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# Image path: images/Ford Explorer 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# Image path: images/Ford F-150 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Image path: images/Ford Fiesta 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Image path: images/Ford Focus 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Image path: images/Ford Fusion 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Image path: images/Ford Fusion Hybrid 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Image path: images/Ford Mach-E 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Image path: images/Ford Maverick 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# Image path: images/Ford Mustang 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step
# Image path: images/Ford Mustang Mach 1 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# Image path: images/Ford Puma 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# Image path: images/Ford Ranger 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Image path: images/Ford Transit 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Image path: images/Geely Binrui 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# Image path: images/Geely Binrui 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# Image path: images/Geely Binyue 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# Image path: images/Geely Boyue 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Image path: images/Geely Coolray 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# Image path: images/Geely Emgrand EC7 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Image path: images/Geely Emgrand EC8 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# Image path: images/Geely Emgrand GL 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step
# Image path: images/Geely Emgrand GS 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Image path: images/Geely Emgrand X7 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 795ms/step
# Image path: images/Geely Haoyue 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Image path: images/Geely Icon 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step
# Image path: images/Geely Vision Starburst 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# Image path: images/Geely Yuanjing X3 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step
# Image path: images/GMC Acadia 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 815ms/step
# Image path: images/GMC Sierra 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# Image path: images/GMC Terrain 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step
# Image path: images/Great Wall Coolbear 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step
# Image path: images/Great Wall Haval H2 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# Image path: images/Great Wall Haval H5 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step
# Image path: images/Great Wall Haval H6 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 885ms/step
# Image path: images/Great Wall Haval H7 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 780ms/step
# Image path: images/Great Wall Haval H9 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 827ms/step
# Image path: images/Great Wall Ora Black Cat 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# Image path: images/Great Wall Ora Cyber Cat 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# Image path: images/Great Wall Ora Haomao 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 824ms/step
# Image path: images/Great Wall Ora Punk Cat 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 801ms/step
# Image path: images/Great Wall Ora R2 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step
# Image path: images/Great Wall Pao 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 576ms/step
# Image path: images/Great Wall Tank 300 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# Image path: images/Great Wall Voleex C20R 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# Image path: images/Great Wall Wingle 5 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step
# Image path: images/Great Wall Wingle 7 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 825ms/step
# Image path: images/Honda Accord 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# Image path: images/Honda Accord Hybrid 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step
# Image path: images/Honda City 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step
# Image path: images/Honda Civic 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step
# Image path: images/Honda Civic Type R 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Image path: images/Honda Clarity 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 782ms/step
# Image path: images/Honda CR-V 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step
# Image path: images/Honda CR-V Hybrid 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# Image path: images/Honda Fit 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# Image path: images/Honda HR-V 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 592ms/step
# Image path: images/Honda HR-V e:HEV 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# Image path: images/Honda Insight 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 789ms/step
# Image path: images/Honda Odyssey 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step
# Image path: images/Honda Passport 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 864ms/step
# Image path: images/Honda Pilot 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# Image path: images/Honda Ridgeline 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# Image path: images/Hyundai Accent 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# Image path: images/Hyundai Elantra 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 808ms/step
# Image path: images/Hyundai Elantra N 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step
# Image path: images/Hyundai Genesis G70 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# Image path: images/Hyundai Ioniq 5 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step
# Image path: images/Hyundai Ioniq Hybrid 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# Image path: images/Hyundai Kona 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 893ms/step
# Image path: images/Hyundai Palisade 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 813ms/step
# Image path: images/Hyundai Santa Cruz 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# Image path: images/Hyundai Santa Fe 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# Image path: images/Hyundai Sonata 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# Image path: images/Hyundai Sonata Hybrid 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# Image path: images/Hyundai Tucson 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 829ms/step
# Image path: images/Hyundai Veloster 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 816ms/step
# Image path: images/Hyundai Veloster N 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# Image path: images/Hyundai Venue 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step
# Image path: images/Isuzu D-Max 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# Image path: images/Isuzu D-Max Hi-Lander 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# Image path: images/Isuzu D-Max Hi-Lander 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# Image path: images/Isuzu D-Max V-Cross 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# Image path: images/Isuzu ELF 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 767ms/step
# Image path: images/Isuzu Forward 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# Image path: images/Isuzu F-Series 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 897ms/step
# Image path: images/Isuzu F-Series 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Image path: images/Isuzu FTR 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Image path: images/Isuzu Giga 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Image path: images/Isuzu MU-X 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# Image path: images/Isuzu MU-X 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 742ms/step
# Image path: images/Isuzu MU-X 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# Image path: images/Isuzu NPR 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Image path: images/Isuzu N-Series 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Image path: images/Isuzu N-Series 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Image path: images/Li ONE 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Image path: images/Li Xiang ONE 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# Image path: images/Li Xiang ONE 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 752ms/step
# Image path: images/Lucid Air 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step
# Image path: images/Lucid Air Pure 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Image path: images/Lucid Air Touring 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# Image path: images/Mahindra Alturas G4 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# Image path: images/Mahindra Bolero 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Image path: images/Mahindra Bolero Neo 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 862ms/step
# Image path: images/Mahindra e2o Plus 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# Image path: images/Mahindra KUV100 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step
# Image path: images/Mahindra Marazzo 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Image path: images/Mahindra NuvoSport 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# Image path: images/Mahindra Scorpio 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step
# Image path: images/Mahindra Thar 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# Image path: images/Mahindra Thar 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# Image path: images/Mahindra TUV300 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step
# Image path: images/Mahindra Verito 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# Image path: images/Mahindra XUV300 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# Image path: images/Mahindra XUV400 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# Image path: images/Mahindra XUV500 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# Image path: images/Mahindra XUV700 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# Image path: images/Mazda CX-20 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Image path: images/Mazda CX-3 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# Image path: images/Mazda CX-30 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 679ms/step
# Image path: images/Mazda CX-4 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# Image path: images/Mazda CX-5 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# Image path: images/Mazda CX-50 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Image path: images/Mazda CX-9 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# Image path: images/Mazda MX-30 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Image path: images/Mazda MX-5 Miata 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Image path: images/Mazda MX-5 Miata RF 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step
# Image path: images/Mazda MX-6 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# Image path: images/Mazda3 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Image path: images/Mazda3 Hatchback 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# Image path: images/Mazda5 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Image path: images/Mazda6 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 794ms/step
# Image path: images/Mazda6 Turbo 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step
# Image path: images/Mercedes-Benz A-Class 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# Image path: images/Mercedes-Benz AMG GT 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step
# Image path: images/Mercedes-Benz C-Class 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Image path: images/Mercedes-Benz CLA Coupe 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Image path: images/Mercedes-Benz CLA-Class 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step
# Image path: images/Mercedes-Benz CLS-Class 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Image path: images/Mercedes-Benz E-Class 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# Image path: images/Mercedes-Benz EQC 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step
# Image path: images/Mercedes-Benz EQS 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step
# Image path: images/Mercedes-Benz G-Class 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Image path: images/Mercedes-Benz GLA-Class 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# Image path: images/Mercedes-Benz GLA-Class 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Image path: images/Mercedes-Benz GLB-Class 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# Image path: images/Mercedes-Benz GLC Coupe 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# Image path: images/Mercedes-Benz GLC-Class 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 662ms/step
# Image path: images/Mercedes-Benz GLE-Class 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step
# Image path: images/Mercedes-Benz GLS-Class 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# Image path: images/Mercedes-Benz S-Class 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# Image path: images/Mercedes-Benz S-Class 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Image path: images/Mercedes-Benz SL-Class 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Image path: images/NIO ES5 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Image path: images/NIO ES9 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Image path: images/Nissan 370Z 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 772ms/step
# Image path: images/Nissan Altima 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Image path: images/Nissan Ariya 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# Image path: images/Nissan GT-R 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Image path: images/Nissan Juke 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# Image path: images/Nissan Kicks 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# Image path: images/Nissan Maxima 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Image path: images/Nissan Murano 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Image path: images/Nissan NV200 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 840ms/step
# Image path: images/Nissan Pathfinder 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Image path: images/Nissan Rogue 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# Image path: images/Nissan Sentra 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# Image path: images/Nissan Terra 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step
# Image path: images/Nissan Titan 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Image path: images/Nissan Versa 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# Image path: images/Nissan Z 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step
# Image path: images/Polaris General 1000 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Image path: images/Polaris Indy 600 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Image path: images/Polaris Ranger EV 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Image path: images/Polaris Ranger XP 900 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Image path: images/Polaris RZR Pro XP 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 810ms/step
# Image path: images/Polaris RZR XP 1000 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 757ms/step
# Image path: images/Polaris Slingshot 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step
# Image path: images/Polaris Slingshot R 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# Image path: images/Polaris Sportsman 570 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# Image path: images/Polaris Sportsman XP 1000 S 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Image path: images/Polestar 3 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# Image path: images/Polestar 4 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# Image path: images/Renault Arkana 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# Image path: images/Renault Captur 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 779ms/step
# Image path: images/Renault Captur II 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# Image path: images/Renault Clio 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Image path: images/Renault Fluence 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Image path: images/Renault Kadjar 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# Image path: images/Renault Koleos 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# Image path: images/Renault Laguna 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Image path: images/Renault Megane 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# Image path: images/Renault Megane E-Tech Electric 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 680ms/step
# Image path: images/Renault Scenic 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Image path: images/Renault Talisman 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step
# Image path: images/Renault Twingo 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# Image path: images/Renault Twizy 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# Image path: images/Renault Wind 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# Image path: images/Renault Zoe 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step
# Image path: images/Rivian Amazon Delivery Van.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# Image path: images/Rivian R2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step
# Image path: images/Stellantis 200X.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# Image path: images/Stellantis Fusion.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Image path: images/Stellantis Horizon.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# Image path: images/Stellantis Nova.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# Image path: images/Stellantis Strada.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Image path: images/Stellantis Voyager.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# Image path: images/Subaru Ascent 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Image path: images/Subaru Baja 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Image path: images/Subaru BRZ 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 905ms/step
# Image path: images/Subaru Crosstrek 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Image path: images/Subaru Crosstrek Hybrid 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 763ms/step
# Image path: images/Subaru Exiga 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 814ms/step
# Image path: images/Subaru Forester 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 576ms/step
# Image path: images/Subaru Impreza 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# Image path: images/Subaru Legacy 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step
# Image path: images/Subaru Levorg 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# Image path: images/Subaru Outback 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# Image path: images/Subaru Outback Wilderness 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# Image path: images/Subaru Solterra 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# Image path: images/Subaru WRX 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# Image path: images/Subaru WRX STI 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# Image path: images/Subaru XV 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# Image path: images/Suzuki Across 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 783ms/step
# Image path: images/Suzuki Baleno 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 882ms/step
# Image path: images/Suzuki Carry 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Image path: images/Suzuki Every 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step
# Image path: images/Suzuki Ignis 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step
# Image path: images/Suzuki Ignis Hybrid 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 905ms/step
# Image path: images/Suzuki Jimny 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 794ms/step
# Image path: images/Suzuki Jimny Sierra 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# Image path: images/Suzuki S-Cross 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 702ms/step
# Image path: images/Suzuki Solio 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step
# Image path: images/Suzuki Spacia 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Image path: images/Suzuki Swace 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# Image path: images/Suzuki Swift 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# Image path: images/Suzuki Swift Sport 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# Image path: images/Suzuki Vitara 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Image path: images/Suzuki Wagon R 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# Image path: images/Tesla Cybertruck 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Image path: images/Tesla Model 3 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Image path: images/Tesla Model 3 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# Image path: images/Tesla Model 3 Long Range 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# Image path: images/Tesla Model 3 Performance 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# Image path: images/Tesla Model 3 Standard Range Plus 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Image path: images/Tesla Model S 100D 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Image path: images/Tesla Model S 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 797ms/step
# Image path: images/Tesla Model S Long Range 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Image path: images/Tesla Model S P90D 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 986ms/step
# Image path: images/Tesla Model S Plaid 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step
# Image path: images/Tesla Model X 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# Image path: images/Tesla Model X Long Range 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# Image path: images/Tesla Model X P90D 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# Image path: images/Tesla Model X Plaid 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Image path: images/Tesla Model Y 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Image path: images/Tesla Model Y Long Range 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 767ms/step
# Image path: images/Tesla Model Y Standard Range 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# Image path: images/Tesla Roadster 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Image path: images/Tesla Semi 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Image path: images/Toyota 4Runner 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Image path: images/Toyota Avalon 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# Image path: images/Toyota Camry 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Image path: images/Toyota Camry Hybrid 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 791ms/step
# Image path: images/Toyota Corolla 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# Image path: images/Toyota Corolla Cross 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Image path: images/Toyota Corolla Hatchback 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# Image path: images/Toyota Corolla Hybrid 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Image path: images/Toyota Highlander 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# Image path: images/Toyota Prius 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# Image path: images/Toyota Prius C 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# Image path: images/Toyota Prius Prime 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# Image path: images/Toyota RAV4 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# Image path: images/Toyota RAV4 Hybrid 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Image path: images/Toyota Sienna 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# Image path: images/Toyota Supra 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Image path: images/Toyota Tacoma 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# Image path: images/Toyota Tacoma TRD Pro 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# Image path: images/Toyota Tundra 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# Image path: images/Toyota Venza 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# Image path: images/VinFast President 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# Image path: images/VinFast VF e34 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# Image path: images/Volkswagen Amarok 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# Image path: images/Volkswagen Arteon 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# Image path: images/Volkswagen Golf 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# Image path: images/Volkswagen Golf 8 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# Image path: images/Volkswagen ID. Buzz 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# Image path: images/Volkswagen ID.3 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Image path: images/Volkswagen ID.4 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Image path: images/Volkswagen ID.5 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# Image path: images/Volkswagen ID.6 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Image path: images/Volkswagen Multivan 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Image path: images/Volkswagen Passat 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 672ms/step
# Image path: images/Volkswagen Polo 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step
# Image path: images/Volkswagen Polo GTI 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Image path: images/Volkswagen Taigo 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Image path: images/Volkswagen T-Cross 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Image path: images/Volkswagen Tiguan 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Image path: images/Volkswagen Tiguan Allspace 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Image path: images/Volkswagen Touareg 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# Image path: images/Volkswagen T-Roc 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step
# Image path: images/Volvo C30 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# Image path: images/Volvo C40 Recharge 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# Image path: images/Volvo S60 2014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Image path: images/Volvo S60 2019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Image path: images/Volvo S80 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Image path: images/Volvo S90 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Image path: images/Volvo V40 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# Image path: images/Volvo V60 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# Image path: images/Volvo V60 Cross Country 2020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# Image path: images/Volvo V70 2017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# Image path: images/Volvo V90 2016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Image path: images/Volvo XC40 2018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Image path: images/Volvo XC40 Recharge 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# Image path: images/Volvo XC60 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# Image path: images/Volvo XC90 2015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# Image path: images/Volvo XC90 Recharge 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step
# Image path: images/XPeng G9 2023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# Image path: images/XPeng P5 2021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 790ms/step
# Image path: images/XPeng P9 2022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# C:\Users\abdul\AppData\Local\Temp\ipykernel_12816\2055755835.py:59: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Datasets/CNN_car_features.csv')
# Features saved to CNN_car_features.csv

# %% [markdown]
# # Predict Stock price using CNN Features

# %% [markdown]
# First apply PCA to reduce dimension

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

# Load the dataset
input_csv = 'Datasets/CNN_car_features.csv'
output_csv = 'Datasets/CNN_car_featuresPCA.csv'

print("Loading dataset...")
df = pd.read_csv(input_csv)
print(f"Dataset loaded with shape: {df.shape}")

# Separating out the features for PCA (starting from the 5th column to the end)
X = df.iloc[:, 3:].values

# Perform PCA
n_components = 199  # Adjust the number of components based on your needs
print(f"Performing PCA to reduce dimensions to {n_components}...")
pca = PCA(n_components=n_components)
principalComponents = pca.fit_transform(X)

# Creating a DataFrame with the first 5 columns and the principal components
print("Creating DataFrame with the first 5 columns and principal components...")
principalDf = pd.DataFrame(data=principalComponents, columns=[f'PC{i+1}' for i in range(n_components)])

# Combine the first 5 columns with the principal components
result_df = pd.concat([df.iloc[:, :3], principalDf], axis=1)

# Saving the new dataset to a CSV file
print(f"Saving the new dataset to {output_csv}...")
result_df.to_csv(output_csv, index=False)
print("Process completed successfully.")
# Out:
# Loading dataset...
# C:\Users\abdul\AppData\Local\Temp\ipykernel_12816\2579509585.py:10: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_csv)
# Dataset loaded with shape: (398, 25091)
# Performing PCA to reduce dimensions to 199...
# Creating DataFrame with the first 5 columns and principal components...
# Saving the new dataset to Datasets/CNN_car_featuresPCA.csv...
# Process completed successfully.

# %% [markdown]
# Dimension reduced from 1600 to 200

# %% [markdown]
# Predict Stock price using Machine learning model

# %%
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load the CSV file into a DataFrame
df = pd.read_csv('Datasets/CNN_car_featuresPCA.csv')

# Identify the numerical columns
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Standardize all numerical columns
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Specify the directory to save the file
output_directory = 'Datasets/CNN'
os.makedirs(output_directory, exist_ok=True)  # Create the directory if it doesn't exist

# Save the standardized DataFrame to a new CSV file
output_file = os.path.join(output_directory, 'CNN_car_featuresPCAstand.csv')
df.to_csv(output_file, index=False)

print("Standardization complete. The standardized data has been saved to 'Standardized_Dataset.csv' in the '{}' directory.".format(output_directory))
# Out:
# Standardization complete. The standardized data has been saved to 'Standardized_Dataset.csv' in the 'Datasets/CNN' directory.

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Function to perform Linear Regression with Cross-Validation
def perform_linear_regression_cv(df):
    X = df.drop(columns=['Price'])  # Features
    y = df['Price']  # Target variable

    # Linear Regression with Cross-Validation
    linear_reg = LinearRegression()
    mse_scores = -cross_val_score(linear_reg, X, y, cv=5, scoring='neg_mean_squared_error')
    return mse_scores.mean()

# Function to perform XGBoost Regression with Cross-Validation
def perform_xgboost_regression_cv(df):
    X = df.drop(columns=['Price'])  # Features
    y = df['Price']  # Target variable

    # Best parameters for XGBoost Regression
    best_params = {
        'learning_rate': 0.1,
        'max_depth': 3,
        'n_estimators': 100,
        'subsample': 0.8
    }

    # XGBoost Regression with Cross-Validation
    xgb_reg = xgb.XGBRegressor(objective='reg:squarederror', **best_params)
    mse_scores = -cross_val_score(xgb_reg, X, y, cv=5, scoring='neg_mean_squared_error')
    return mse_scores.mean()

# Function to perform Random Forest Regression with Cross-Validation
def perform_random_forest_regression_cv(df):
    X = df.drop(columns=['Price'])  # Features
    y = df['Price']  # Target variable

    # Random Forest Regression with Cross-Validation
    rf_reg = RandomForestRegressor(random_state=42)
    mse_scores = -cross_val_score(rf_reg, X, y, cv=5, scoring='neg_mean_squared_error')
    return mse_scores.mean()

# Function to perform Neural Network Regression with Cross-Validation
def perform_neural_network_regression_cv(df):
    X = df.drop(columns=['Price'])  # Features
    y = df['Price']  # Target variable
    
    # Define the neural network architecture
    model = keras.Sequential([
        layers.Dense(64, activation='relu', input_shape=[X.shape[1]]),
        layers.Dense(64, activation='relu'),
        layers.Dense(1)
    ])
    
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    # Define K-fold cross-validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)
    mse_scores = []
    
    # Perform K-fold cross-validation
    for train_idx, val_idx in kfold.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        # Train the model
        model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=0)
        
        # Evaluate the model on the validation set
        val_loss = model.evaluate(X_val, y_val, verbose=0)
        mse_scores.append(val_loss)
    
    return np.mean(mse_scores)

# Folder containing individual CSV files
folder_path = "Datasets/CNN"

# Function to perform data preprocessing and feature engineering
from category_encoders import TargetEncoder

# Function to preprocess data with enhanced feature engineering and encoding
def preprocess_data(df):

    # Drop original 'Date' and 'Quarter_Date' columns
    df.drop(columns=['CarName'], inplace=True)

    # Use target encoding for the 'Stock' column
    encoder = TargetEncoder()
    df['Stock_Encoded'] = encoder.fit_transform(df['Stock'], df['Price'])

    # Drop the original 'Stock' column
    df.drop(columns=['Stock'], inplace=True)
    
    return df

# Iterate over CSV files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        print("Processing file:", filename)

        df = pd.read_csv(file_path)
        
        # Preprocess data
        df = preprocess_data(df)
        
        # Assuming 'Price' is the target column
        if 'Price' in df.columns:
            # Perform Linear Regression with Cross-Validation
            linear_reg_cv_mse = perform_linear_regression_cv(df)
            print("Cross-Validation MSE (Linear Regression):", linear_reg_cv_mse)
            
            # Perform XGBoost Regression with Cross-Validation
            xgb_reg_cv_mse = perform_xgboost_regression_cv(df)
            print("Cross-Validation MSE (XGBoost Regression):", xgb_reg_cv_mse)
            
            # Perform Random Forest Regression with Cross-Validation
            rf_reg_cv_mse = perform_random_forest_regression_cv(df)
            print("Cross-Validation MSE (Random Forest Regression):", rf_reg_cv_mse)
            
            # Perform Neural Network Regression with Cross-Validation
            nn_reg_cv_mse = perform_neural_network_regression_cv(df)
            print("Cross-Validation MSE (Neural Network Regression):", nn_reg_cv_mse)
        else:
            print("Error: 'Price' column not found in", filename)
# Out:
# Processing file: CNN_car_featuresPCAstand.csv
# Cross-Validation MSE (Linear Regression): 2.204167654192342
# Cross-Validation MSE (XGBoost Regression): 0.46913157372044045
# Cross-Validation MSE (Random Forest Regression): 0.3734591126003731
# D:\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Cross-Validation MSE (Neural Network Regression): 0.24715637173503638
